# %%
import warnings
warnings.filterwarnings("ignore")
import cv2
import numpy as np
import skimage.io
import os
import sys
import matplotlib.pyplot as plt
import math
from scipy import ndimage
import pandas as pd
import seaborn as sns
from random import randint, uniform
from tqdm import tqdm

from collections import Counter
from itertools import permutations, product
from sklearn.cluster import DBSCAN

from sklearn import svm
from sklearn.metrics import confusion_matrix, plot_confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, BatchNormalization, Dense, Dropout, Conv2D, Flatten, MaxPooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)

base_data = './data/val/img'

# %%
# network params
BatchSize = 4
NumChannels = 3
ImgHeight, ImgWidth = 480, 640
NumClass = 1

# data params
TrainImageDir = './data/train/img'
ValImageDir = './data/val/img'

# %%
model = seg_hrnet(BatchSize, ImgHeight, ImgWidth, NumChannels, NumClass)
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=10)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', mode='min', factor=0.1, patience=2)

model_path = "seg_hrnet-{epoch:02d}-{val_loss:.4f}-{val_acc:.4f}-{val_iou:.4f}.h5"
model_checkpoint = ModelCheckpoint(os.path.join('model',model_path), monitor='val_loss', mode='min', verbose=1, save_best_only=True)

check_point_list = [model_checkpoint, early_stop, reduce_lr]

# %%
train, train_steps = batch_generator(TrainImageDir, BatchSize, seed = 0, flag = 'train')
val, val_steps = batch_generator(ValImageDir, BatchSize, seed = 0, flag = 'val')

# %%
plt.figure(figsize=(20,10))
row = 5

for i in range(row):
    img, mask = next(train)
    for j in range(BatchSize):
        plt.subplot(row,BatchSize,i*BatchSize+j+1)
        image = cv2.cvtColor((img[j]* 255).astype(np.uint8), cv2.COLOR_BGR2RGB)
        gt = cv2.cvtColor((mask[j]* 255).astype(np.uint8), cv2.COLOR_BGR2RGB)
        plt.imshow(cv2.bitwise_or(image,gt))

# %%
plt.figure(figsize=(20,10))

for i in range(row):
    img, mask = next(val)
    for j in range(BatchSize):
        plt.subplot(row,BatchSize,i*BatchSize+j+1)
        image = cv2.cvtColor((img[j]* 255).astype(np.uint8), cv2.COLOR_BGR2RGB)
        gt = cv2.cvtColor((mask[j]* 255).astype(np.uint8), cv2.COLOR_BGR2RGB)
        plt.imshow(cv2.bitwise_or(image,gt))

# %%
result = model.fit_generator(generator = train,
                             steps_per_epoch = train_steps,
                             epochs = 25,
                             verbose = 1,
                             validation_data = val,
                             validation_steps = val_steps,
                             callbacks = check_point_list)

# %%
plt.figure()
plt.plot(result.epoch, result.history['loss'], label="loss")
plt.plot(result.epoch, result.history['val_loss'], label="val_loss")
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Clean picture test

# %%
img = cv2.imread(os.path.join(base_data,'clear.jpg'))[:, :, [2, 1, 0]]

# %%
# plt.figure(figsize=(20,20))
# for idx, bb in enumerate(bbox):
#     x0, x1, y0, y1 = bb
#     img_tile = img[y0:y1,x0:x1]
#     plt.subplot(9,9,idx+1)
# #     plt.imshow(img_tile)
#     inv = np.uint8(np.invert(gray[y0:y1,x0:x1]))
#     plt.imshow(inv)
#     plt.axis('off')
#     img_resize = cv2.resize(inv, (28,28), interpolation=cv2.INTER_LINEAR).flatten().reshape(1, -1)
#     l = clf.predict(img_resize) if np.max(inv) > 10 else None
#     plt.title('%s'%(l))
                           
# plt.tight_layout()

# %%
plt.figure(figsize=(20,20))
for idx, bb in enumerate(bbox):
    x0, x1, y0, y1 = bb
    img_tile = img[y0:y1,x0:x1]
    plt.subplot(9,9,idx+1)
    inv = np.uint8(np.invert(gray[y0:y1,x0:x1]))
    plt.imshow(inv)
    plt.axis('off')
    img_resize = cv2.resize(inv, (28,28), interpolation=cv2.INTER_LINEAR).reshape(-1,28,28,1)
    l = [np.argmax(k, axis=None, out=None) for k in model.predict(img_resize, verbose=0)] if np.max(inv) > 150 else None
    plt.title('%s'%(l),fontsize=20)
                           
plt.tight_layout()

# %%
t = data[target==7]

plt.figure(figsize=(20,20))
for idx, img_test in enumerate(t[:81]):
    plt.subplot(9,9,idx+1)
    plt.imshow(img_test.reshape(28,28))
    plt.axis('off')

# %%
# # Find solution for sudoku
# x = Counter(grid_number)
# number = sorted(x, key=x.get, reverse=True)
# for n in number:
#     print(n)
